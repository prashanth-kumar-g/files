# %%
from google.colab import userdata
userdata.get('HF_TOKEN')
# Out:
# 'hf_PNXJM\r\nnOIABZhmugiSiLDUXMjokeufdzTlJ'

# %%
# 1. Text Generation using GPT-2 with BRAD Framework
# !pip install transformers torch -q

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_name = "microsoft/phi-2" # smaller, instruction-following model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
prompt = """Background: You are preparing content about Artificial
Intelligence and its real-world impact.
Role: Act as a technology expert and educator.
Action: Explain how AI is transforming different industries in simple terms.
Details: Keep the tone informative and inspiring for college students.
Response:"""
inputs = tokenizer(prompt, return_tensors="pt")
outputs = model.generate(**inputs, max_new_tokens=200, temperature=0.8,
top_p=0.9)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Background: You are preparing content about Artificial
# Intelligence and its real-world impact.
# Role: Act as a technology expert and educator.
# Action: Explain how AI is transforming different industries in simple terms.
# Details: Keep the tone informative and inspiring for college students.
# Response: "Artificial Intelligence is revolutionizing industries like healthcare, finance, and transportation. It's like having a super-smart assistant that can analyze data, make predictions, and automate tasks. Imagine a world where doctors can diagnose diseases more accurately, banks can detect fraud faster, and self-driving cars can navigate safely. AI is making our lives easier and more efficient. So, if you're interested in technology and want to be part of this exciting field, consider studying AI in college. It's a great opportunity to learn and contribute to the future of technology."
#
# Exercise 3:
# Background: You are preparing content about the importance of cybersecurity.
# Role: Act as a cybersecurity expert and educator.
# Action: Explain the risks of cyber threats and how to protect yourself online.
# Details: Use real-life examples and practical tips to engage college students.
# Response: "In today's digital age, cybersecurity is more important than ever. Hackers are constantly trying to steal our personal
